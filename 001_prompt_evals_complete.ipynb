# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
# Function to generate a new dataset
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
        "format": "json" or "python" or "regex",
        "solution_criteria": "Key criteria for evaluating the solution"
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
# Generate the dataset and write it to 'dataset.json'
dataset = generate_dataset()
with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
# Function to grade a test case + output using a model
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Criteria you should use to evaluate the solution:
<criteria>
{test_case["solution_criteria"]}
</criteria>

Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
    """

    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text)

# %%
# Passes a test case into Claude
def run_prompt(test_case):
    prompt = f"""
Please solve the following task:

{test_case["task"]}

* Respond only with Python, JSON, or a plain Regex
* Do not add any comments or commentary or explanation
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```code")
    output = chat(messages, stop_sequences=["```"])
    return output

# %%
# Functions to validate the output structure
import re
import ast


def validate_json(text):
    try:
        json.loads(text.strip())
        return 10
    except json.JSONDecodeError:
        return 0


def validate_python(text):
    try:
        ast.parse(text.strip())
        return 10
    except SyntaxError:
        return 0


def validate_regex(text):
    try:
        re.compile(text.strip())
        return 10
    except re.error:
        return 0


def grade_syntax(response, test_case):
    format = test_case["format"]
    if format == "json":
        return validate_json(response)
    elif format == "python":
        return validate_python(response)
    else:
        return validate_regex(response)

# %%
# Function to execute a single test case and grade the output
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)

    model_grade = grade_by_model(test_case, output)
    model_score = model_grade["score"]
    reasoning = model_grade["reasoning"]

    syntax_score = grade_syntax(output, test_case)

    score = (model_score + syntax_score) / 2

    return {
        "output": output,
        "test_case": test_case,
        "score": score,
        "reasoning": reasoning,
    }

# %%
from statistics import mean


def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    average_score = mean([result["score"] for result in results])
    print(f"Average score: {average_score}")

    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)
# Out:
# Average score: 6.5

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "\nimport json\nimport re\nfrom datetime import datetime\n\ndef parse_cloudwatch_logs_event(event):\n    \"\"\"\n    Parse an AWS CloudWatch Logs event and extract timestamp, log level, and message.\n    \n    Args:\n        event: CloudWatch Logs event (dict or JSON string)\n    \n    Returns:\n        Dictionary with timestamp, log_level, and message\n    \"\"\"\n    if isinstance(event, str):\n        event = json.loads(event)\n    \n    # Decompress and decode the log data\n    if 'awslogs' in event:\n        import base64\n        import gzip\n        \n        compressed_payload = base64.b64decode(event['awslogs']['data'])\n        uncompressed_payload = gzip.decompress(compressed_payload)\n        log_data = json.loads(uncompressed_payload)\n    else:\n        log_data = event\n    \n    results = []\n    \n    if 'logEvents' in log_data:\n        for log_event in log_data['logEvents']:\n            message = log_event.get('message', '')\n            timestamp = log_event.get('timestamp')\n            \n            # Parse log level from message\n            log_level_match = re.search(r'\\b(DEBUG|INFO|WARN|WARNING|ERROR|FATAL|CRITICAL)\\b', message, re.IGNORECASE)\n            log_level = log_level_match.group(1).upper() if log_level_match else 'INFO'\n            \n            # Convert timestamp from milliseconds to ISO format\n            if timestamp:\n                dt = datetime.utcfromtimestamp(timestamp / 1000.0)\n                timestamp_str = dt.isoformat() + 'Z'\n            else:\n                timestamp_str = None\n            \n            results.append({\n                'timestamp': timestamp_str,\n                'log_level': log_level,\n                'message': message.strip()\n            })\n    \n    return results[0] if len(results) == 1 else results\n",
#     "test_case": {
#       "task": "Parse an AWS CloudWatch Logs event and extract the timestamp, log level, and message fields",
#       "format": "python",
#       "solution_criteria": "Function should correctly parse JSON log events and return a dictionary with 'timestamp', 'level', and 'message' keys. Should handle missing fields gracefully."
#     },
#     "score": 7.5,
#     "reasoning": "The solution demonstrates strong AWS CloudWatch Logs handling with proper decompression logic and timestamp conversion. However, it has critical issues with the output schema: it returns 'log_level' instead of 'level', and inconsistently returns either a dict or list depending on event count. The regex-based log level extraction is also problematic for real-world use cases where log levels may be in structured fields rather than plaintext messages. These issues directly violate the stated criteria."
#   },
#   {
#     "output": "\n{\n  \"Version\": \"2012-10-17\",\n  \"Statement\": [\n    {\n      \"Effect\": \"Allow\",\n      \"Action\": [\n        \"ec2:DescribeInstances\",\n        \"ec2:StartInstances\"\n      ],\n      \"Resource\": \"*\"\n    }\n  ]\n}\n",
#     "test_case": {
#       "task": "Create a JSON IAM policy document that allows EC2 DescribeInstances and StartInstances actions on all resources",
#       "format": "json",
#       "solution_criteria": "Valid JSON with correct structure including Version, Statement array with Effect, Action, and Resource fields. Actions should be limited to ec2:DescribeInstances and ec2:StartInstances."
#     },
#     "score": 8.5,
#     "reasoning": "The solution technically meets the stated requirements with correct JSON syntax and the exact actions specified. However, it follows the literal instruction to allow actions on 'all resources' without considering AWS security best practices. While this may be acceptable for a learning exercise or sandbox environment, production policies should implement least-privilege access with restricted resource ARNs."
#   },
#   {
#     "output": "\nimport re\n\ndef extract_s3_bucket_names(arns):\n    \"\"\"Extract S3 bucket names from S3 ARNs.\"\"\"\n    pattern = r'arn:aws:s3:::([^/]+)'\n    bucket_names = []\n    \n    for arn in arns:\n        match = re.search(pattern, arn)\n        if match:\n            bucket_names.append(match.group(1))\n    \n    return bucket_names\n\n\n# Test cases\ntest_arns = [\n    \"arn:aws:s3:::my-bucket\",\n    \"arn:aws:s3:::my-bucket/path/to/object\",\n    \"arn:aws:s3:::another-bucket\",\n    \"arn:aws:s3:::bucket-with-dashes\",\n    \"arn:aws:s3:::my-bucket-123\"\n]\n\nresult = extract_s3_bucket_names(test_arns)\nprint(result)\n",
#     "test_case": {
#       "task": "Extract AWS S3 bucket names from S3 ARNs using a regular expression",
#       "format": "regex",
#       "solution_criteria": "Regex should match S3 ARNs in format 'arn:aws:s3:::bucket-name' and 'arn:aws:s3:::bucket-name/key' and capture only the bucket name. Should work with bucket names containing hyphens and numbers."
#     },
#     "score": 3.5,
#     "reasoning": "The solution correctly solves the core requirement of extracting bucket names from S3 ARNs using regex. The pattern `arn:aws:s3:::([^/]+)` effectively captures the bucket name before any path components. However, the implementation lacks robustness in input validation and doesn't enforce AWS S3 bucket naming rules. The solution works for the given test cases but could fail or produce unexpected results with malformed input."
#   }
# ]
